# %% [markdown]
# ### 실습6

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[['sepal_width','sepal_length', 'species']]
# Out:
#      sepal_width  sepal_length    species
# 0            3.5           5.1     setosa
# 1            3.0           4.9     setosa
# 2            3.2           4.7     setosa
# 3            3.1           4.6     setosa
# 4            3.6           5.0     setosa
# ..           ...           ...        ...
# 145          3.0           6.7  virginica
# 146          2.5           6.3  virginica
# 147          3.0           6.5  virginica
# 148          3.4           6.2  virginica
# 149          3.0           5.9  virginica
#
# [150 rows x 3 columns]

# %%
columns=['sepal_width','sepal_length', 'species']
df[columns]
# Out:
#      sepal_width  sepal_length    species
# 0            3.5           5.1     setosa
# 1            3.0           4.9     setosa
# 2            3.2           4.7     setosa
# 3            3.1           4.6     setosa
# 4            3.6           5.0     setosa
# ..           ...           ...        ...
# 145          3.0           6.7  virginica
# 146          2.5           6.3  virginica
# 147          3.0           6.5  virginica
# 148          3.4           6.2  virginica
# 149          3.0           5.9  virginica
#
# [150 rows x 3 columns]

# %%
df[columns].head()
# Out:
#    sepal_width  sepal_length species
# 0          3.5           5.1  setosa
# 1          3.0           4.9  setosa
# 2          3.2           4.7  setosa
# 3          3.1           4.6  setosa
# 4          3.6           5.0  setosa

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df['sepal_width'].head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
df['sepal_length'].head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
df.sepal_length.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
# 정규표현식

# %%
# _(under_bar)가 들어간 컬럼만 가져옴
df.filter(regex='_')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.filter(regex='length$')  # 끝나는 부분 $
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
df.filter(regex='es$')
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
df.filter(regex='^sepal')   #시작하는 부분 ^
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df.filter(regex='^pe')
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
df.filter(regex='^(?!species$).*')  # species 관련 문자가 포함되지 않도록 필터링
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.loc[2:4] # 범위 마지막까지 갖고 옴
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.loc[2:5, 'sepal_width':'petal_length']
# Out:
#    sepal_width  petal_length
# 2          3.2           1.3
# 3          3.1           1.5
# 4          3.6           1.4
# 5          3.9           1.7

# %%
df.iloc[:3,[1,3]]
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2

# %%
df.iloc[:3, 1:3]  # 범위 마지막 안 갖고 옴
# Out:
#    sepal_width  petal_length
# 0          3.5           1.4
# 1          3.0           1.4
# 2          3.2           1.3

# %%
df.loc[df['sepal_length']>5, ['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 5             5.4          3.9
# 10            5.4          3.7
# 14            5.8          4.0
# 15            5.7          4.4
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [118 rows x 2 columns]

# %%
df.loc[df['sepal_length']>5, ['sepal_length','sepal_width']].head()
# Out:
#     sepal_length  sepal_width
# 0            5.1          3.5
# 5            5.4          3.9
# 10           5.4          3.7
# 14           5.8          4.0
# 15           5.7          4.4
